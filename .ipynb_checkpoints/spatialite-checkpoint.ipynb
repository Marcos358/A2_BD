# %%
#! sudo apt-get install libsqlite3-mod-spatialite spatialite-bin
#! pip install -U sqlalchemy geoalchemy geoalchemy2

# %%
import sqlalchemy, json
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.event import listen
from sqlalchemy.sql import select, func
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy.orm import relationship, backref

from geoalchemy2 import Geometry, WKTElement

# %%
def load_spatialite(dbapi_conn, connection_record):
    dbapi_conn.enable_load_extension(True)
    dbapi_conn.load_extension('/usr/lib/x86_64-linux-gnu/mod_spatialite.so')

# %%
try:
    os.remove('gis.sqlite')
    print("removed file")
except:
    print("file in use or not found")
# Out:
# file in use or not found

# %%
#engine = create_engine('postgresql://gis:gis@localhost/gis', echo=True)
engine = create_engine('sqlite:///gis.sqlite', echo=True)
listen(engine, 'connect', load_spatialite)

# %%
conn = engine.connect()

# %%
conn.execute(select([func.InitSpatialMetaData()]))
# Out:
# 2021-11-19 16:53:05,266 INFO sqlalchemy.engine.Engine SELECT InitSpatialMetaData() AS "InitSpatialMetaData_1"
# 2021-11-19 16:53:05,271 INFO sqlalchemy.engine.Engine [generated in 0.00554s] ()

# %%
Base = declarative_base()

class Irrigacao(Base):
    __tablename__ = 'irrigacoes'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    geom = Column(Geometry(geometry_type='POLYGON', management=True))

# %%
f = open('A2_BD/geoteste.geojson','r', encoding = 'utf8')
s = f.read()
f.close()

# %%
#Irrigacao.__table__.create(engine)

# %%
Irrigacao.__table__
# Out:
# Table('irrigacoes', MetaData(), Column('id', Integer(), table=<irrigacoes>, primary_key=True, nullable=False), Column('name', String(), table=<irrigacoes>), Column('geom', Geometry(geometry_type='POLYGON', management=True, from_text='ST_GeomFromEWKT', name='geometry'), table=<irrigacoes>), schema=None)

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
f = open('A2_BD/geoteste.geojson')
data = json.load(f)

for i in data['features']:
   # print(i)#i.keys(), i['properties'].keys(), i['geometry'].keys())
    break

# %%
irrigacoes = Irrigacao(name='Majeur', geom='POLYGON((0 0,1 0,1 1,0 1,0 0))')
session.add(irrigacoes)
#session.commit()

# %%
import geopandas as gpd

# %%
full_data = gpd.read_file('brazil.json')

# %%
full_data2 = gpd.read_file('area_irrigada.geojson')

# %%
fig, ax = full_data.plot(figsize = (8,8), color = 'r')
full_data2.plot(figsize = (8,8), color = 'b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4921d9a7104e> in <module>
# ----> 1 fig, ax = full_data.plot(figsize = (8,8), color = 'r')
#       2 full_data2.plot(figsize = (8,8), color = 'b')
#
# TypeError: cannot unpack non-iterable AxesSubplot object

# %%
ax = full_data.plot(figsize=(10,10), color='none', edgecolor='gainsboro', zorder=0.5)

full_data2.plot(figsize = (10,10), color = 'b', ax=ax)
# Out:
# <AxesSubplot:>
